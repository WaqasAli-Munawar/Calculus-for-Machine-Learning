# %% [markdown]
# In last project, we learned how to use limits to calculate the point a function approaches when the input value approaches a specific value. We applied this technique to calculate the slope of the tangent line at a specific point on our nonlinear function: $y = -(x)^2 + 3x - 1$

# %% [markdown]
# Our main objective is to determine the highest point on this curve.

# %% [markdown]
# If we've ever hiked a mountain before, we'll be familiar with how the trail slopes up until we reach the peak. Once we're at the peak, however, all of the paths back down slope downwards. Understanding how the slope varies throughout a curve provides a useful lens for determining the maximum point on a curve.

# %% [markdown]
# We'll start by building some visual intuition for how a function's slope and it's maximum point are related.

# %%
from IPython.display import Image

Image("tangent_slope-view.gif")

# %% [markdown]
# In the image above, we've generated two plots. As **x** varies, the plot on the left visualizes how the tangent line for the curve changes while the plot on the right visualizes how the slope of this tangent line changes.

# %% [markdown]
# When **x** is less than 1.5, the slope is positive. As x approaches 1.5 from the left side, the slope decreases and approaches 0. At x=1.5, the slope of the tangent line is exactly 0. When we increased x past 1.5 the slope of the tangent line becomes increasingly negative. The highest point on our curve acts as a kind of transition point from positive slope to negative slope.

# %% [markdown]
# By plotting the slopes at many different x values, we can tell that they follow a straight line. This line can be described as its own function, and is known as the **derivative**. A function's derivative can tell us the slope of the tangent line for any x value along the function.

# %% [markdown]
# So far, we've been solving for the slope at specific points by plugging in the specific x value into the slope equation as expressed as a limit. To find the general function that describes the slope at any point, we need to solve the limit using the original variable instead of replacing with a specific x value.

# %% [markdown]
# Instead of using $x_1$ and $x_2$ in the slope equation, let's use **x and x+h**. This version of the slope equation is how most textbooks and resources refer to slope:![image.png](attachment:image.png)

# %% [markdown]
# In this form, **h** represents the distance between the 2 points: x and x+h. The slope is the value the limit approaches as h approaches 0

# %%
Image("slope_h_form.gif")

# %% [markdown]
# The process of finding a function's derivative is known as **differentiation**. Instead of selecting a specific x value, we'll leave x where it is and expand the equation to solve for the derivative.Since $f(x) = -(x)^2 + 3x -1$, this works out to:![image.png](attachment:image.png)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-5,6,110)

y_dash = -2*x+3
plt.plot(x,y_dash)
plt.show()

# %% [markdown]
# The line plot we generated is one of the from that visualizes how the slope changes for different **x** values. We use the following notation to specify that $-2x + 3$ is our curve's derivative:

# %% [markdown]
# $y' = -2x + 3$

# %% [markdown]
# The following is an alternative form of notation, which makes it clear that the derivative of y is a function of x: ![image.png](attachment:image.png)

# %% [markdown]
# Earlier, we discussed how the slope at x = 1.5 was 0 and acted as a transition point from positive slope to negative slope. This is formally known as a **critical point**. At a function's critical point, the slope is either 0 or undefined. Not all critical points act as transition points for slopes

# %%
Image("critical_points.gif")

# %% [markdown]
# The above image visualizes the slope for **$y=x^3$** and lets us explore how the slope changes before and after the critical point. We can notice how the slope remains positive before and after the critical point.

# %% [markdown]
# We observed how the slope didn't change from positive to negative at the critical point. Critical points are interesting to us in data science when they represent **extreme values**. Extreme values can be split into 2 categories -- minimum and maximum. As we noticed at the beginning of this project, a critical point can be a minimum value if the slope transitions from negative to positive at that point. When the slope transitions from positive to negative at a point, it can be a maximum value. If the slope doesn't transition at a critical point, like at **x=0** for $y=x^3$  above, then it can't be a minimum or a maximum point.

# %% [markdown]
# A curve can have multiple critical points and multiple candidates for minimum and maximum values. The following curve has 3 critical points and all 3 meet the criteria of transitioning slope from positive to negative or negative to positive. At the same time, none of the values are the highest points on the curve (while one of them seems to be the lowest).![image.png](attachment:image.png)

# %% [markdown]
# These values are known as local extrema, since they're the lowest or highest value in the interval surrounding each point. If a critical point is the lowest point in the interval surrounding it, it's known as a **relative minimum**. If it's the highest point in the neighborhood, it's known as a **relative maximum**.![image.png](attachment:image.png)

# %% [markdown]
# Since we know that relative minimums and maximums can occur when the slope is 0, we can solve for the critical points using arithmetic (instead of relying on just the graph). To calculate the critical point for our original curve, we need to set our derivative function to 0 and solve for x.
#
# -2x + 3 = 0
#
# after solving equation we get
#
# x = 1.5

# %% [markdown]
# This matches the value we observed visually in the first graph in this file. Since this curve only had 1 critical point and the slope transitioned from positive to negative, we can safely say that this is a relative maximum.

# %% [markdown]
# We calculated the derivative for our curve using a limit and working out the arithmetic. We then set the derivative function to  0 and calculated the critical points. This approach can be painful to do for more complex functions like $y = x^5 - x$ because we'll need to replace x with  x+h and expand the exponent $(x+h)^5$:![image.png](attachment:image.png)

# %% [markdown]
# We can instead apply derivative rules to more easily calculate the derivative function.
#
# The first rule is the [power rule](https://en.wikipedia.org/wiki/Power_rule), which helps us take the derivative for functions with exponents.![image.png](attachment:image.png)

# %% [markdown]
# Calculate the derivative of $f(x) = x^5$

# %%
derivative = "5*(x**4)"

# Slope at x = 2

slope = 5*(2**4)
slope
# Out:
# 80

# %% [markdown]
# Another important set of rules is [linearity of differentiation](https://en.wikipedia.org/wiki/Linearity_of_differentiation). We'll switch to using the $d/dx$ notation when discussing these rules. Like with limit functions, we can separate mathematical terms that are being added or subtracted and differentiate them separately.![image.png](attachment:image.png)

# %% [markdown]
# Calculate the derivative of $f(x) = x^3 - x^2$

# %%
derivative = "3x^2 - 2x"

# slope at  x = 2

slope = 3*2**2 - 2*2
slope
# Out:
# 8

# %% [markdown]
# In the past, we started by plotting the curve and visually observing where the critical points could be. This time around, we're not going to paint a visual picture and will instead use arithmetic to find the extreme values.

# %% [markdown]
# We'll need to first set $3x^2 - 2x$ to 0 and solve for **x**. Once we've found the critical point(s), we can analyze the slope around the point(s) to see if slope transitions from positive to negative or vice versa.

# %% [markdown]
# To analyze the direction of the slope, we use a [sign chart](http://www.rasmus.is/uk/t/F/Su53k02.htm). With a sign chart, we only care about if a given point in a region comes out positive or negative. This tool makes it great to analyze the direction of the slope (positive or negative).
#
# We can test points around our points of interest to see if there is a sign change as well as what the change is.

# %%
# critical points for 3x^2 - 2x.

derivative = "3x^2 - 2x"

"3x^2 - 2x = 0"
"x(3x - 2) = 0"
"x = 0 & x = 2/3"

critical_points = [0,2/3]

rel_min = [2/3]  # critical point is a relative minimum
rel_max = [0]    # critical point is a relative maximum

# %% [markdown]
# In this project, we explored how to calculate the derivative for a function and find extreme values. We now have the groundwork necessary to understand how linear regression models are fit
